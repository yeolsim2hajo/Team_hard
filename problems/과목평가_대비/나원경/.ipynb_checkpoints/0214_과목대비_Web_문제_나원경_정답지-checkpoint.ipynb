# %% [markdown]
# **220214 과목평가 대비 문제**
#
# (단답형은 답만 적고, 서술형은 100자 이상 적어야 정답처리됨)
#
# 단답형 - 결괏값, 빈칸 채우기
#
# 객관식 - 개념, 결괏값
#
# 서술형 - 기본 개념, 지문의 출력 결과와 그 이유

# %% [markdown]
# *아래 문제의 제목은 열심히 만든 착한말 생성기를 사용할 일이 별로 없음에 슬퍼하던 출제자가 이 기회를 빌려 착한말 생성기를 작동해 나온 결과를 바탕으로 작성했음을 알립니다.*

# %% [markdown]
# htm –html 기본 구조, DOM, 시맨틱 태그, 주요 태그와 속성 (table, form, input X)

# %% [markdown]
# css – 단위 (크기, 속성), 선택자 및 우선순위, 박스 모델, 인라인, 블록, Position(static, relative, absolute (out of flow), float(X), fixed (axis, containter, item, 각 속성)

# %% [markdown]
# 반응형 웹 – bootstrap(grid system, breakpoint)

# %% [markdown]
# 마크업 – 각 태그별 속성(인라인, 블록)
# 스타일링
# 레이아웃 – display 분석, box model – flex, bootstrap system
# 스타일 –color, size, 각 태그별 속성

# %% [markdown]
# # 사람들한테 희재님 좋아하는 사람 손 들라 했더니 지구가 성게가 된 거 아세요?
#
# (차분하고 열정적) 주관식
# 부트스트랩

# %%
정답 :

# %% [markdown]
# # 장엽님 평소에 인상 좋다는 얘기 많이 들으시죠?
#
# 장엽은 web 공부를 하며 ~~

# %% [markdown]
# 1. HTML과 CSS를 작성할 때보다 빠른 마크업을 위해 사용되는 오픈소스로, 단축키와 약어 등을 사용한다.
# 2.
# 3. 메타 데이터를 표현하는 새로운 규약
# 4. 태그 등을 이용해 문서나 데이터의 구조를 명시하는 언어
# 5. 텍스트 파일인 HTML 문서를 브라우저에서 렌더링하기 위한 구조로, HTML 문서 내의 각 요소에 접근/수정에 필요한 프로퍼티와 메서드를 제공한다.

# %%
1. Emmet

3. Open Graph Protocol
4. Markup Language
5. DOM(Document Object Model)

# %% [markdown]
# # 서준님 오늘따라 참 머리가 괜찮아보이네요.
#
# 옳지 않은 것을 고르시오. (각 2점, 총 10점)

# %% [markdown]
# ##
#
# 1. HTML에서 요소는 중첩될 수 있는데, 여는 태그와 닫는 태그의 쌍이 맞지 않으면 레이아웃이 깨진 상태로 출력돼.
# 2. a 태그와 img 태그는 인라인 요소야.
# 3. margin을 설정할 때 값이 세 개면 각각 상하, 좌, 우를 의미해.
# 4. 기본적으로 모든 요소는 padding 영역을 제외한 contents 영역만을 box로 지정해.
# 5. 블록 레벨 요소 안에 인라인 레벨 요소가 들어갈 수 있어.

# %%
정답 : 3 상, 좌우, 하를 의미

# %% [markdown]
# ##
#
# 1. inline-block은 inline처럼 한 줄에 표시 가능하고, block처럼 width, height, margin 속성을 모두 지정할 수 있어.
# 2. block의 기본 너비는 가질 수 있는 너비의 100%이고, 너비를 가질 수 없다면 자동으로 margin이 부여돼.
# 3. display에서 none은 해당 요소를 화면에 표시하지 않는 건데 공간은 차지해.
# 4. Position의 기본값은 static이고 부모 요소 내에서 배치될 때 부모 요소의 위치를 기준으로 배치돼.
# 5. relative는 기준 위치 대비 offset한 것으로 이동하더라도 요소가 차지하는 공간은 유지돼.

# %%
정답 : 3 (one은 공간조차 부여되지 않고 visulality hidden은 공간을 차지하나 화면에 표시되지 않음)

# %% [markdown]
# ##
#
# 1. absolute는 가장 가까이 있는 부모/조상 요소 기준으로 이동해. 없는 경우에는 body를 기준으로 이동해.

# %% [markdown]
# ##

# %% [markdown]
# ##

# %% [markdown]
# # 한님 좀 거품인 것 같아요. 언빌리버블.

# %% [markdown]
# 다음은 한이 작성한 unbelievable.css 파일이다. 주석에 적어놓은 요구사항대로 작동하도록 빈칸을 채우시오.

# %% [markdown]
# 사진

# %% [markdown]
# ![css_box.png](attachment:css_box.png)

# %%
1. margin-left: auto;
2. text-align: right;
3. .water
4. flex-flow: column wrap;
5. #bubble
6.justify-content: space-around;
7. align-items: center; # 보류

# %% [markdown]
# # 와, 역시 대단해. 웹엑스를 찢어놓으셨다.
#
# 원경은 웹엑스를 찢어놓을 만한 실력을 갖추기 위해 노력했지만, 애써 작성한 문서가 망하고 말았다. 다행히도 열심히 하조 조원들이 원경을 도와주겠다고 했고 원경은 자신의 코드와 구현하고자 하는 내용을 설명하기 시작했다. 원경을 도와 문서를 완성하시오.

# %%
주관식 - 망한 문서 구하기

‘=’ 사이 공백을 주지 않고 쌍따옴표 사용
태그별로 사용할 수 있는 속성은 다름
요소는 속성을 가질 수 있으며, 경로나 크기와 같은 추가적인 정보 제공
id : 문서 전체에서 유일한 고유 식별자 지정
    
    CSS 적용 우선 순위
    CSS 상속
    가변적인 레이아웃에서 자주 사용 - %
    viewport 웹 페이지를 방문한 유저에게 바로 보이게 되는 웹 컨텐츠의 영역 (디바이스 화면)
    디바이스의 viewport를 기준으로 상대적 크기가 결정됨
    
    자손 결합자
    자식 결합자
    일반 형제 결합자
    인접 형제 결합자
    
    emmet
    
    
    
    제목 없음 사진
    네스팅 - 조원들 이름
    열심히 하조
    하지만 스파르타

# %% [markdown]
# # 한님 승마장 출입금지 당했죠? 한님 보면 말이 안 나와서....

# %%
서술형

부트스트랩?

# %% [markdown]
# # 나 서른 살인데 동년배들 다 서준님 좋아한다.

# %% [markdown]
# 1. div 태그를 대체하는, 의미를 담은 태그를 (    )라고 한다. 빈칸에 들어갈 용어와 이러한 태그 예시 3가지(위에 나온 태그 제외), 이를 사용했을 때의 장점 2가지를 쓰시오. (각 1점, 총 6점)
#
#
# 2. CSS 정의 방법 세 가지와, 가장 많이 쓰이는 방법의 장점을 서술하시오. (각 1점, 총 4점)

# %%
정답 : 
1. 시맨틱 태그
header, nav, aside, section, article, footer, h1, table
단순히 구역을 나누는 것뿐만 아니라 의미를 가지는 태그를 활용하면 요소의 의미가 명확해지기 때문에
코드의 가독성이 높아지고 검색을 쉽게할 수 있어 유지 보수가 쉬워진다. (검색엔진 최적화)

# %%
정답:
2. CSS 정의 방법에는 해당 태그에 직접 style 속성을 활용하는 인라인, head 태그 내에 style 태그를 지정하는 내부 참조, 외부 CSS 파일을
<head> 내 <link>를 통해 불러오는 외부 참조가 있다. html 문서를 작성하다보면 코드가 길어지는데, css까지 html 문서에 작성하다보면
가독성이 좋지 않아 외부 참조를 가장 많이 사용한다.

# %% [markdown]
# # 희재님 어디 계시죠? 제 눈에는 빛밖에 안 보이는데.

# %% [markdown]
# 언제나 열정적인 희재는 web 공부를 하다가 자신의 열정을 담을 수 있는 html 문서를 작성하기 시작했다. 희재가 작성한 html 문서 상단부에서 가려진 부분을 채우시오. (각 1점, 총 9점)
#
# (사진이 뜨지 않을 시 Ctrl+Enter를 누르면 됩니다.)

# %% [markdown]
# ![yeol_jeong-2.jpg](attachment:yeol_jeong-2.jpg)

# %%
정답 :
    1. !DOCTYPE
    2. html
    3. head
    4. meta
    5. charset
    6. link
    7. rel
    8. href
    9. title
# Out:
#   File "C:\Users\pubha\AppData\Local\Temp\ipykernel_30684\1871327676.py", line 1
#     정답 :
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 정말 C급이에요. 광주 3반의 문화재 지정이 시급.

# %%
서술형
종합?

# %% [markdown]
# # 정말 KT에서 고소당하시겠어요. 장엽님이 정말 GIGA 막혀서.

# %%
t/f
1. href 속성은 a 태그와만 쓰인다.
2. src 속성은 img 태그에서 이미지를 표현하는 데 활용된다.
3. em  태그는 중요한 강조하고자 하는 요소를 나타내고, 보통 굵은 글씨로 표현된다.
4. ul 태그는 순서가 있는 리스트를 표현할 때 사용된다.
5. rem은 최상위 요소의 크기를 기준으로 배수 단위이며, 보통 최상위 요소의 기본값은 24px이다.
6. 색상 키워드는 대소문자를 구별하지 않는다.
7.
8. 
9. 모든 HTML 요소는 box 형태로 되어있고 하나의 box는 네 부분(영역)으로 이루어진다.
10. RGB로 색상을 표현할 때는 16진수 표기법과 함수형 표기법을 사용한다.

# %%
1. F
2. T
3. F
4. F
5. F (16px)
6. T


9. T
10. T

# %% [markdown]
# 아래는 추가 문제입니다. 시간이 날 때 풀어보세요.

# %% [markdown]
# # table (T/F)
#
# 1. 표를 만들기 위해서는 반드시 thead, tbody, tfoot 요소를 순서대로 사용해야 한다.
# 2. 가로줄을 표현할 때 thead에서 사용하는 태그와 tbody에서 사용하는 태그가 다르다.
# 3. caption은 tfoot에 위치한다.
# 4. thead를 구성하기 위해서는 th를 먼저 쓴 후에 tr을 써야 한다.

# %%
1. F (thead와 tfoot은 사용하지 않아도 됨)
2. F (tr로 같음, 세로 줄을 표현할 때가 th, td로 다름)
3. F (caption은 tfoot 아래에 위치)
4. F (tr을 쓴 후에 th를 써야 함)

# %% [markdown]
# # input (T/F)
#
# 1. 이름과 값이 쌍으로 전송된다.
# 2. input label을 사용할 때 label에는 id 속성을, input에는 for 속성을 연관시킨다.
# 3. input 유형에서 password를 사용하면 입력 시 값이 보이지 않고 문자가 특수문자로 표현된다.
# 4. radio button은 한 가지만 선택할 수 있다는 데 반해, checkbox는 여러 가지를 선택할 수 있다.
# 5. 사용자 입력을 받지 않고 서버에 전송되어야 하는 값은 hidden을 이용한다.

# %%
1. T
2. F (label과 input 설명 반대)
3. T
4. T
5. T

# %% [markdown]
# # form (T/F)
#
# 1. form은 정보를 서버에 제출하기 위한 영역이다.
# 2. action의 값은 form을 처리할 서버의 URL이다.
# 3. method의 값으로 GET이나 POST를 쓴다.

# %%
정답 : 전부 T

# %%
float
